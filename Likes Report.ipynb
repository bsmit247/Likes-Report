# %% [markdown]
# # Likes Report
# ## Breena Smith
# ### 09/10/2024
#
# I don't have Instagram nor Facebook, but I used to have a tiktok I was active on up until 2 years ago, so I hope even with the time gap I'll be able to find the data that is needed. For the Instagram and Facebook I am using the data give to me by Professor Silva

# %%
import json
import pandas as pd

# %% [markdown]
# For this first part of the code I wanted to do the Instagram data, and just take it a step at a time to see what I could find out within the data I was borrowing from Professor Silva.

# %%
path = "liked_posts.json"

with open (path) as j:
    liked = json.load(j)

# %%
liked.keys()
# Out:
# dict_keys(['likes_media_likes'])

# %%
liked['likes_media_likes']
# Out:
# [{'title': 'gu.comm.unity',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C-UPsphucGL/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1722982058}]},
#  {'title': 'gonzagacas',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C-N3u6tOBNs/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1722713263}]},
#  {'title': 'batotoyetuportugal',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C97vrPfsF3j/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1722102612}]},
#  {'title': 'melissarohwer',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C92viGvMcyu/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1721931691}]},
#  {'title': 'catsandkilos',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C90VZRFSuXv/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1721864550}]},
#  {'title': 'cacandassociates',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C9JLwXJONx0/',
# ...

# %%
liked['likes_media_likes'][0]
# Out:
# {'title': 'gu.comm.unity',
#  'string_list_data': [{'href': 'https://www.instagram.com/p/C-UPsphucGL/',
#    'value': 'ð\x9f\x91\x8d',
#    'timestamp': 1722982058}]}

# %% [markdown]
# I struggled with trying to get ahold of the timestamp data. I kept coming back up here or trying to move on. It took me coming back the next day before it all clicked to me. I looked back to what we had done in class and used the x for in x as if it was like y=mx+b and plugged in my information, and that led me to getting ahold of the timestamp data.

# %%
liked_df = pd.DataFrame(liked['likes_media_likes'])
liked_df.head()
# Out:
#                 title                                   string_list_data
# 0       gu.comm.unity  [{'href': 'https://www.instagram.com/p/C-UPsph...
# 1          gonzagacas  [{'href': 'https://www.instagram.com/p/C-N3u6t...
# 2  batotoyetuportugal  [{'href': 'https://www.instagram.com/p/C97vrPf...
# 3       melissarohwer  [{'href': 'https://www.instagram.com/reel/C92v...
# 4        catsandkilos  [{'href': 'https://www.instagram.com/p/C90VZRF...

# %%
liked_df['string_list_data']
# Out:
# 0      [{'href': 'https://www.instagram.com/p/C-UPsph...
# 1      [{'href': 'https://www.instagram.com/p/C-N3u6t...
# 2      [{'href': 'https://www.instagram.com/p/C97vrPf...
# 3      [{'href': 'https://www.instagram.com/reel/C92v...
# 4      [{'href': 'https://www.instagram.com/p/C90VZRF...
#                              ...
# 495    [{'href': 'https://www.instagram.com/p/VOvhh-I...
# 496    [{'href': 'https://www.instagram.com/p/VS8uQHj...
# 497    [{'href': 'https://www.instagram.com/p/VTEGrND...
# 498    [{'href': 'https://www.instagram.com/p/VC6yAyN...
# 499    [{'href': 'https://www.instagram.com/p/T43xRFj...
# Name: string_list_data, Length: 500, dtype: object

# %%
liked_df['string_list_data'].iloc [0]
# Out:
# [{'href': 'https://www.instagram.com/p/C-UPsphucGL/',
#   'value': 'ð\x9f\x91\x8d',
#   'timestamp': 1722982058}]

# %%
liked_df['string_list_data'].iloc [0][0]
# Out:
# {'href': 'https://www.instagram.com/p/C-UPsphucGL/',
#  'value': 'ð\x9f\x91\x8d',
#  'timestamp': 1722982058}

# %%
liked_df['string_list_data'].iloc [0][0] ['timestamp']
# Out:
# 1722982058

# %%
[x[0]['timestamp'] for x in liked_df['string_list_data']]
# Out:
# [1722982058,
#  1722713263,
#  1722102612,
#  1721931691,
#  1721864550,
#  1720424567,
#  1719825538,
#  1719276309,
#  1718315056,
#  1717711186,
#  1716937699,
#  1716851405,
#  1716577228,
#  1715647355,
#  1714890108,
#  1714600857,
#  1713654890,
#  1712784014,
#  1711756385,
#  1711454120,
#  1711404353,
#  1711312497,
#  1710681004,
#  1710617843,
#  1710617809,
#  1709855615,
#  1709763752,
#  1708986768,
#  1708785432,
#  1708692593,
#  1708121653,
#  1707660717,
#  1704574606,
#  1704164022,
#  1702944558,
#  1701914412,
#  1701620382,
#  1701471943,
#  1701290923,
#  1701139029,
#  1700859096,
#  1700620253,
#  1700054225,
#  1699415639,
#  1699141190,
#  1696786997,
#  1695947601,
#  1695692997,
#  1694004209,
#  1693959836,
#  1692831359,
#  1692276165,
#  1690495555,
#  1690403521,
#  1690246959,
#  1690170128,
#  1689588744,
#  1689315027,
#  1686185708,
#  1686170244,
#  1685925708,
#  1685500090,
#  1684839147,
#  1684756710,
#  1682374361,
#  1681957326,
# ...

# %%
liked_df['Time Liked']=[x[0]['timestamp'] for x in liked_df['string_list_data']]

# %%
liked_df.head()
# Out:
#                 title                                   string_list_data  \
# 0       gu.comm.unity  [{'href': 'https://www.instagram.com/p/C-UPsph...
# 1          gonzagacas  [{'href': 'https://www.instagram.com/p/C-N3u6t...
# 2  batotoyetuportugal  [{'href': 'https://www.instagram.com/p/C97vrPf...
# 3       melissarohwer  [{'href': 'https://www.instagram.com/reel/C92v...
# 4        catsandkilos  [{'href': 'https://www.instagram.com/p/C90VZRF...
#
#    Time Liked
# 0  1722982058
# 1  1722713263
# 2  1722102612
# 3  1721931691
# 4  1721864550

# %%
liked_df1 = pd.DataFrame([x[0] for x in liked_df['string_list_data']])

# %%
liked_df1.head()
# Out:
#                                           href value   timestamp
# 0     https://www.instagram.com/p/C-UPsphucGL/  ð  1722982058
# 1     https://www.instagram.com/p/C-N3u6tOBNs/  ð  1722713263
# 2     https://www.instagram.com/p/C97vrPfsF3j/  ð  1722102612
# 3  https://www.instagram.com/reel/C92viGvMcyu/  ð  1721931691
# 4     https://www.instagram.com/p/C90VZRFSuXv/  ð  1721864550

# %%
liked_df1 ['title'] = liked_df ['title']
liked_df1.head()
# Out:
#                                           href value   timestamp  \
# 0     https://www.instagram.com/p/C-UPsphucGL/  ð  1722982058
# 1     https://www.instagram.com/p/C-N3u6tOBNs/  ð  1722713263
# 2     https://www.instagram.com/p/C97vrPfsF3j/  ð  1722102612
# 3  https://www.instagram.com/reel/C92viGvMcyu/  ð  1721931691
# 4     https://www.instagram.com/p/C90VZRFSuXv/  ð  1721864550
#
#                 title
# 0       gu.comm.unity
# 1          gonzagacas
# 2  batotoyetuportugal
# 3       melissarohwer
# 4        catsandkilos

# %%
liked_df1.groupby('title').count()
# Out:
#                          href  value  timestamp
# title
# a_matt_silva               18     18         18
# adventuresofcassidyrose     1      1          1
# ali_saurusrex              94     94         94
# andrewtcurry                1      1          1
# aroseroar16                30     30         30
# ...                       ...    ...        ...
# thewestonpatrick            1      1          1
# transitionbikes             1      1          1
# tslemmer                    3      3          3
# vitalmtb                    1      1          1
# wrenchscienceusa            1      1          1
#
# [80 rows x 3 columns]

# %%
liked_df1.groupby('title').count().sort_values('value', ascending = False).head(10)
# Out:
#                   href  value  timestamp
# title
# ali_saurusrex       94     94         94
# cacandassociates    41     41         41
# ccikentstate        31     31         31
# aroseroar16         30     30         30
# orangekoala2        29     29         29
# inalull             24     24         24
# reams_esq           23     23         23
# a_matt_silva        18     18         18
# colin_storm         18     18         18
# danneabreanne       17     17         17

# %% [markdown]
# Now that I have what I want from the instagram data, I decide to move over to the facebook data. While I don't use facebook, Dr. Silva does so using his data, I'm curious to see his friends list and feed have to offer.

# %%
path = "feed.json"

with open (path) as j:
    feed = json.load(j)

# %%
feed.keys()
# Out:
# dict_keys(['people_and_friends_v2'])

# %%
feed['people_and_friends_v2']
# Out:
# [{'name': 'Unfollow',
#   'description': "Friends, Pages and groups that you've unfollowed to stop seeing their posts.",
#   'entries': [{'timestamp': 1669776922,
#     'data': {'name': 'Brian G Smith',
#      'uri': 'https://www.facebook.com/briang.smith.5264'}},
#    {'timestamp': 1638542608,
#     'data': {'name': 'WSU Free & For Sale - Pullman, WA',
#      'uri': 'https://www.facebook.com/groups/WSUFreeAndForSalePullman/'}},
#    {'timestamp': 1613958377,
#     'data': {'name': 'Linda Vanderpool',
#      'uri': 'https://www.facebook.com/linda.vanderpool.10'}},
#    {'timestamp': 1609863498,
#     'data': {'name': "Men in the Arena - Christian Men's Group",
#      'uri': 'https://www.facebook.com/groups/144084032765210/'}},
#    {'timestamp': 1609348013,
#     'data': {'name': 'John Hickey',
#      'uri': 'https://www.facebook.com/john.hickey.3990'}},
#    {'timestamp': 1599779191,
#     'data': {'name': 'WSU GPSA', 'uri': 'https://facebook.com/wsu.gpsa'}},
# ...

# %%
type(feed['people_and_friends_v2'])
# Out:
# list

# %%
feed['people_and_friends_v2'][1]
# Out:
# {'name': 'See less',
#  'description': "Profiles and Pages that you've recently chosen to see less of in your Feed",
#  'entries': [{'timestamp': 1431715836,
#    'data': {'name': 'Orrin Burger',
#     'uri': 'https://www.facebook.com/orrin.burger'}}]}

# %%
feed_df = pd.DataFrame(feed['people_and_friends_v2'])
feed_df.head()
# Out:
#        name                                        description  \
# 0  Unfollow  Friends, Pages and groups that you've unfollow...
# 1  See less  Profiles and Pages that you've recently chosen...
#
#                                              entries
# 0  [{'timestamp': 1669776922, 'data': {'name': 'B...
# 1  [{'timestamp': 1431715836, 'data': {'name': 'O...

# %%
feed_df['entries']
# Out:
# 0    [{'timestamp': 1669776922, 'data': {'name': 'B...
# 1    [{'timestamp': 1431715836, 'data': {'name': 'O...
# Name: entries, dtype: object

# %%
type(feed_df['entries'])
# Out:
# pandas.core.series.Series

# %%
feed_df['entries'].iloc[0]
# Out:
# [{'timestamp': 1669776922,
#   'data': {'name': 'Brian G Smith',
#    'uri': 'https://www.facebook.com/briang.smith.5264'}},
#  {'timestamp': 1638542608,
#   'data': {'name': 'WSU Free & For Sale - Pullman, WA',
#    'uri': 'https://www.facebook.com/groups/WSUFreeAndForSalePullman/'}},
#  {'timestamp': 1613958377,
#   'data': {'name': 'Linda Vanderpool',
#    'uri': 'https://www.facebook.com/linda.vanderpool.10'}},
#  {'timestamp': 1609863498,
#   'data': {'name': "Men in the Arena - Christian Men's Group",
#    'uri': 'https://www.facebook.com/groups/144084032765210/'}},
#  {'timestamp': 1609348013,
#   'data': {'name': 'John Hickey',
#    'uri': 'https://www.facebook.com/john.hickey.3990'}},
#  {'timestamp': 1599779191,
#   'data': {'name': 'WSU GPSA', 'uri': 'https://facebook.com/wsu.gpsa'}},
#  {'timestamp': 1599779191,
#   'data': {'name': 'FIFA World Cup',
#    'uri': 'https://facebook.com/fifaworldcup'}},
#  {'timestamp': 1599779191,
# ...

# %%
feed_df['entries'].iloc[0][3]
# Out:
# {'timestamp': 1609863498,
#  'data': {'name': "Men in the Arena - Christian Men's Group",
#   'uri': 'https://www.facebook.com/groups/144084032765210/'}}

# %%
[x[0]['timestamp'] for x in feed_df['entries']]
# Out:
# [1669776922, 1431715836]

# %%
[x[0]['data'] for x in feed_df['entries']]
# Out:
# [{'name': 'Brian G Smith',
#   'uri': 'https://www.facebook.com/briang.smith.5264'},
#  {'name': 'Orrin Burger', 'uri': 'https://www.facebook.com/orrin.burger'}]

# %% [markdown]
# Since I wasn't getting far with the feed, I decided to shift my focus to the your_friends.json and what I could pull from that. I wanted to see what I could from his friends, like who interacted with him the most or liked something of his the most. I'm not really sure how facebook data works but I think that we can find that out with the your_friends.json over the feed one.

# %%
path = "your_friends.json"

with open (path) as j:
    friends = json.load(j)

# %%
friends.keys()
# Out:
# dict_keys(['friends_v2'])

# %%
friends['friends_v2']
# Out:
# [{'name': 'Matthew Craig', 'timestamp': 1722880565},
#  {'name': 'Brad Elsberg', 'timestamp': 1714142873},
#  {'name': 'Kevin Dilley', 'timestamp': 1702658796},
#  {'name': 'Chance York', 'timestamp': 1702524039},
#  {'name': 'Bob Baumann', 'timestamp': 1698712172},
#  {'name': 'Jordan Belisle', 'timestamp': 1664922583},
#  {'name': 'Tq Ha', 'timestamp': 1662127205},
#  {'name': 'Peter Torassa', 'timestamp': 1659371880},
#  {'name': 'Jordan Wickander', 'timestamp': 1654182160},
#  {'name': 'Aditi Rao', 'timestamp': 1645322307},
#  {'name': 'Mafer CastaÃ±eda Diaz', 'timestamp': 1635427068},
#  {'name': 'Jessica Jean', 'timestamp': 1627578476},
#  {'name': 'Hyunjin Seo', 'timestamp': 1627062204},
#  {'name': 'Joy Kern', 'timestamp': 1624422206},
#  {'name': 'Nik Rex', 'timestamp': 1621429604},
#  {'name': 'Kyle Berkson', 'timestamp': 1617720438},
#  {'name': 'Lelee Ounkham', 'timestamp': 1616598376},
#  {'name': 'Katelyn Bradshaw Vanderpool', 'timestamp': 1609208149},
# ...

# %%
friends_df = pd.DataFrame(friends['friends_v2'])
friends_df.head()
# Out:
#             name   timestamp contact_info
# 0  Matthew Craig  1722880565          NaN
# 1   Brad Elsberg  1714142873          NaN
# 2   Kevin Dilley  1702658796          NaN
# 3    Chance York  1702524039          NaN
# 4    Bob Baumann  1698712172          NaN

# %%
friends_df['name']
# Out:
# 0                 Matthew Craig
# 1                  Brad Elsberg
# 2                  Kevin Dilley
# 3                   Chance York
# 4                   Bob Baumann
#                  ...
# 534    Gianpaulo Dragotta Silva
# 535               Adrian Fisher
# 536                Ashley James
# 537               Natalie Silva
# 538                 Alice Silva
# Name: name, Length: 539, dtype: object

# %%
friends_df['name'].iloc [0]
# Out:
# 'Matthew Craig'

# %%
friends_df['contact_info']
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 534    NaN
# 535    NaN
# 536    NaN
# 537    NaN
# 538    NaN
# Name: contact_info, Length: 539, dtype: object

# %%
friend_df_tidy = friends_df.drop(columns = ['contact_info'])
friend_df_tidy
# Out:
#                          name   timestamp
# 0               Matthew Craig  1722880565
# 1                Brad Elsberg  1714142873
# 2                Kevin Dilley  1702658796
# 3                 Chance York  1702524039
# 4                 Bob Baumann  1698712172
# ..                        ...         ...
# 534  Gianpaulo Dragotta Silva  1211486218
# 535             Adrian Fisher  1211478730
# 536              Ashley James  1211465907
# 537             Natalie Silva  1211427727
# 538               Alice Silva  1211427724
#
# [539 rows x 2 columns]

# %%
friend_df_tidy.groupby('name').count()
# Out:
#                     timestamp
# name
# Aaron Patterson             1
# Aaron Rusch                 1
# Aaron Wiebe                 1
# Abigail Ledford             1
# Abigail Ness                1
# ...                       ...
# Yudum Turgut                1
# Zachary Schulz              1
# Zech Davis                  1
# Zechariah Silkwood          1
# Zhaomeng Niu                1
#
# [533 rows x 1 columns]

# %%
friend_df_tidy.groupby('name').count().sort_values('timestamp', ascending = False).head(10)
# Out:
#                           timestamp
# name
# Jose Eduardo Silva Lemus          3
# Josue Ortiz                       3
# Greg Pearson                      2
# Alex Miles                        2
# Mark Baas                         1
# Maggie Penner                     1
# Makenzie Weatherford              1
# Margie Kaplan                     1
# Mariah Silva                      1
# Marilyn Holly                     1

# %% [markdown]
# I was able to pull a list of names, a long with the timestamps.
